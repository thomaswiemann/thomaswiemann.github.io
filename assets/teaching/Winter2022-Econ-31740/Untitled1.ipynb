# %%
# Import Turing and Distributions.
using Turing, Distributions

# Import RDatasets.
using RDatasets

# Import MCMCChains, Plots, and StatPlots for visualizations and diagnostics.
using MCMCChains, Plots, StatsPlots

# Functionality for splitting and normalizing the data.
using MLDataUtils: shuffleobs, splitobs, rescale!

# Functionality for evaluating the model predictions.
using Distances

# Set a seed for reproducibility.
using Random
Random.seed!(0)

# Hide the progress prompt while sampling.
Turing.setprogress!(false);
# Out:
# ArgumentError: Package RDatasets not found in current path:
# - Run `import Pkg; Pkg.add("RDatasets")` to install the RDatasets package.
#
#
# Stacktrace:
#  [1] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:893
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
import Pkg
Pkg.add("Turing")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed FFTW_jll ─────────────────── v3.3.10+0
#    Installed Adapt ────────────────────── v3.3.3
#    Installed AdvancedVI ───────────────── v0.1.3
#    Installed MCMCChains ───────────────── v5.0.3
#    Installed IterTools ────────────────── v1.4.0
#    Installed AdvancedHMC ──────────────── v0.3.2
#    Installed ConstructionBase ─────────── v1.3.0
#    Installed NaturalSort ──────────────── v1.0.0
#    Installed MCMCDiagnosticTools ──────── v0.1.3
#    Installed Functors ─────────────────── v0.2.7
#    Installed IntelOpenMP_jll ──────────── v2018.0.3+2
#    Installed MKL_jll ──────────────────── v2021.1.1+2
#    Installed OffsetArrays ─────────────── v1.10.8
#    Installed Turing ───────────────────── v0.19.4
#    Installed ProgressMeter ────────────── v1.7.1
#    Installed CommonSolve ──────────────── v0.2.0
#    Installed EllipticalSliceSampling ──── v0.4.6
#    Installed WoodburyMatrices ─────────── v0.5.5
#    Installed Transducers ──────────────── v0.4.68
#    Installed InplaceOps ───────────────── v0.3.0
#    Installed Roots ────────────────────── v1.3.14
#    Installed MicroCollections ─────────── v0.1.2
#    Installed FFTW ─────────────────────── v1.4.5
#    Installed Tracker ──────────────────── v0.2.17
#    Installed AbstractTrees ────────────── v0.3.4
#    Installed NNlib ────────────────────── v0.7.34
#    Installed CompositionsBase ─────────── v0.1.1
#    Installed AdvancedPS ───────────────── v0.2.4
#    Installed ProgressLogging ──────────── v0.1.4
#    Installed RealDot ──────────────────── v0.1.0
#    Installed IntervalSets ─────────────── v0.5.3
#    Installed Baselet ──────────────────── v0.1.1
#    Installed Setfield ─────────────────── v0.8.1
#    Installed KernelDensity ────────────── v0.6.3
#    Installed BangBang ─────────────────── v0.3.34
#    Installed Libtask ──────────────────── v0.5.3
#    Installed LeftChildRightSiblingTrees ─ v0.1.3
#    Installed ArgCheck ─────────────────── v2.1.0
#    Installed Combinatorics ────────────── v1.0.2
#    Installed ScientificTypesBase ──────── v3.0.0
#    Installed EllipsisNotation ─────────── v1.1.1
#    Installed LoggingExtras ────────────── v0.4.7
#    Installed Interpolations ───────────── v0.13.5
#    Installed RecipesBase ──────────────── v1.2.1
#    Installed TreeViews ────────────────── v0.3.0
#    Installed DistributionsAD ──────────── v0.6.32
#    Installed AdvancedMH ───────────────── v0.6.6
#    Installed MLJModelInterface ────────── v1.3.5
#    Installed AbstractFFTs ─────────────── v1.1.0
#    Installed ChainRules ───────────────── v1.12.1
#    Installed SciMLBase ────────────────── v1.26.0
#    Installed RangeArrays ──────────────── v0.3.2
#    Installed TerminalLoggers ──────────── v0.1.5
#    Installed Libtask_jll ──────────────── v0.4.3+0
#    Installed ConsoleProgressMonitor ───── v0.1.2
#    Installed Ratios ───────────────────── v0.4.2
#    Installed DefineSingletons ─────────── v0.1.2
#    Installed InitialValues ────────────── v0.3.1
#    Installed StatisticalTraits ────────── v3.0.0
#    Installed DynamicPPL ───────────────── v0.17.3
#    Installed AxisAlgorithms ───────────── v1.0.1
#    Installed AbstractMCMC ─────────────── v3.2.1
#    Installed ZygoteRules ──────────────── v0.2.2
#    Installed MappedArrays ─────────────── v0.4.1
#    Installed RecursiveArrayTools ──────── v2.24.0
#    Installed AbstractPPL ──────────────── v0.3.1
#    Installed AxisArrays ───────────────── v0.4.4
#    Installed Bijectors ────────────────── v0.9.11
#    Installed SplittablesBase ──────────── v0.1.14
#    Installed NamedArrays ──────────────── v0.9.6
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [fce5fe82] + Turing v0.19.4
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.1.0
#   [80f14c24] + AbstractMCMC v3.2.1
#   [7a57a42e] + AbstractPPL v0.3.1
#   [1520ce14] + AbstractTrees v0.3.4
#   [79e6a3ab] + Adapt v3.3.3
#   [0bf59076] + AdvancedHMC v0.3.2
#   [5b7e9947] + AdvancedMH v0.6.6
#   [576499cb] + AdvancedPS v0.2.4
#   [b5ca4192] + AdvancedVI v0.1.3
#   [dce04be8] + ArgCheck v2.1.0
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [39de3d68] + AxisArrays v0.4.4
#   [198e06fe] + BangBang v0.3.34
#   [9718e550] + Baselet v0.1.1
#   [76274a88] + Bijectors v0.9.11
#   [082447d4] + ChainRules v1.12.1
#   [861a8166] + Combinatorics v1.0.2
#   [38540f10] + CommonSolve v0.2.0
#   [a33af91c] + CompositionsBase v0.1.1
#   [88cd18e8] + ConsoleProgressMonitor v0.1.2
#   [187b0558] + ConstructionBase v1.3.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [ced4e74d] + DistributionsAD v0.6.32
#   [366bfd00] + DynamicPPL v0.17.3
#   [da5c29d0] + EllipsisNotation v1.1.1
#   [cad2338a] + EllipticalSliceSampling v0.4.6
#   [7a1cc6ca] + FFTW v1.4.5
#   [d9f16b24] + Functors v0.2.7
#   [22cec73e] + InitialValues v0.3.1
#   [505f98c9] + InplaceOps v0.3.0
#   [a98d9a8b] + Interpolations v0.13.5
#   [8197267c] + IntervalSets v0.5.3
#   [c8e1da08] + IterTools v1.4.0
#   [5ab0869b] + KernelDensity v0.6.3
#   [1d6d02ad] + LeftChildRightSiblingTrees v0.1.3
#   [6f1fad26] + Libtask v0.5.3
#   [e6f89c97] + LoggingExtras v0.4.7
#   [c7f686f2] + MCMCChains v5.0.3
#   [be115224] + MCMCDiagnosticTools v0.1.3
#   [e80e1ace] + MLJModelInterface v1.3.5
#   [dbb5928d] + MappedArrays v0.4.1
#   [128add7d] + MicroCollections v0.1.2
#   [872c559c] + NNlib v0.7.34
#   [86f7a689] + NamedArrays v0.9.6
#   [c020b1a1] + NaturalSort v1.0.0
#   [6fe1bfb0] + OffsetArrays v1.10.8
#   [33c8b6b6] + ProgressLogging v0.1.4
#   [92933f4c] + ProgressMeter v1.7.1
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.2
#   [c1ae055f] + RealDot v0.1.0
#   [3cdcf5f2] + RecipesBase v1.2.1
#   [731186ca] + RecursiveArrayTools v2.24.0
#   [f2b01f46] + Roots v1.3.14
#   [0bca4576] + SciMLBase v1.26.0
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [efcf1570] + Setfield v0.8.1
#   [171d559e] + SplittablesBase v0.1.14
#   [64bff920] + StatisticalTraits v3.0.0
#   [5d786b92] + TerminalLoggers v0.1.5
#   [9f7883ad] + Tracker v0.2.17
#   [28d57a85] + Transducers v0.4.68
#   [a2a6695c] + TreeViews v0.3.0
#   [fce5fe82] + Turing v0.19.4
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [700de1a5] + ZygoteRules v0.2.2
#   [f5851436] + FFTW_jll v3.3.10+0
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [3ae2931a] + Libtask_jll v0.4.3+0
#   [856f044c] + MKL_jll v2021.1.1+2
#   [4af54fe1] + LazyArtifacts
# Precompiling project...
#   ✓ CommonSolve
#   ✓ CompositionsBase
#   ✓ InplaceOps
#   ✓ TreeViews
#   ✓ ScientificTypesBase
#   ✓ ArgCheck
#   ✓ LoggingExtras
#   ✓ ProgressLogging
#   ✓ Functors
#   ✓ MappedArrays
#   ✓ WoodburyMatrices
#   ✓ RecipesBase
#   ✓ Adapt
#   ✓ AbstractTrees
#   ✓ NaturalSort
#   ✓ RealDot
#   ✓ DefineSingletons
#   ✓ RangeArrays
#   ✓ InitialValues
#   ✓ IterTools
#   ✓ Ratios
#   ✓ Baselet
#   ✓ ProgressMeter
#   ✓ ConstructionBase
#   ✓ ConsoleProgressMonitor
#   ✓ LeftChildRightSiblingTrees
#   ✓ StatisticalTraits
#   ✓ Combinatorics
#   ✓ AxisAlgorithms
#   ✓ EllipsisNotation
#   ✓ IntelOpenMP_jll
#   ✓ AbstractFFTs
#   ✓ ZygoteRules
#   ✓ Libtask_jll
#   ✓ TerminalLoggers
#   ✓ OffsetArrays
#   ✓ MLJModelInterface
#   ✓ FFTW_jll
#   ✓ Setfield
#   ✓ Libtask
#   ✓ NamedArrays
#   ✓ IntervalSets
#   ✓ MKL_jll
#   ✓ SplittablesBase
#   ✓ AxisArrays
#   ✓ MCMCDiagnosticTools
#   ✓ BangBang
#   ✓ NNlib
#   ✓ MicroCollections
#   ✓ Roots
#   ✓ Interpolations
#   ✓ RecursiveArrayTools
#   ✓ ChainRules
#   ✓ Transducers
#   ✓ Bijectors
#   ✓ AbstractMCMC
#   ✓ FFTW
#   ✓ AbstractPPL
#   ✓ SciMLBase
#   ✓ Tracker
#   ✓ AdvancedPS
#   ✓ AdvancedMH
#   ✓ DistributionsAD
#   ✓ EllipticalSliceSampling
#   ✓ AdvancedHMC
#   ✓ KernelDensity
#   ✓ AdvancedVI
#   ✓ MCMCChains
#   ✓ DynamicPPL
#   ✓ Turing
#   70 dependencies successfully precompiled in 23 seconds (67 already precompiled)
